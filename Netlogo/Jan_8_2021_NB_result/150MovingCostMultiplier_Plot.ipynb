# %%
import pandas as pd 
from pandas import DataFrame
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, show, savefig, xlim, figure, \
                ylim, legend, boxplot, setp, axes

# %% [markdown]
# # Condition

# %%
# from PIL import Image
# myImage = Image.open("");
# myImage

# %% [markdown]
# # 10-year flood

# %%
df1 = pd.read_csv('150M_10_No_NB.csv')
df11 = pd.read_csv('150M_10_3of5_NB.csv')
df12 = pd.read_csv('150M_10_3of7_NB.csv')
df13 = pd.read_csv('150M_10_3of10_NB.csv')

# %%
df1_count = df1.mot_year.value_counts().sort_index()
df11_count = df11.mot_year.value_counts().sort_index()
df12_count = df12.mot_year.value_counts().sort_index()
df13_count = df13.mot_year.value_counts().sort_index()
# df13_count

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year, Moving Cost Multiplier = 150)')

df1_count.cumsum().plot()
df11_count.cumsum().plot()
df12_count.cumsum().plot()
df13_count.cumsum().plot()

plt.xlim([5,40])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['No neighborhood effect','self-moved + 3 out 5 neighbors have moved','self-moved + 3 out 7 neighbors have moved','self-moved + 3 out 10 neighbors have moved']) 

plt.show()

# %%
df1_count_ori = df1.ori_year.value_counts().sort_index()
df11_count_ori = df11.ori_year.value_counts().sort_index()
df12_count_ori = df12.ori_year.value_counts().sort_index()
df13_count_ori = df13.ori_year.value_counts().sort_index()
df13_count_ori
# Out:
# 19     667
# 20     951
# 21    1048
# 22    1144
# 23     536
# 24     297
# 25     258
# 26     195
# 27     118
# 28      34
# 29       2
# 30       3
# 31      11
# 32      24
# 33      29
# 34      81
# 35     217
# 36     251
# Name: ori_year, dtype: int64

# %%
fig = figure(figsize=(15, 8))
plot2 = plt.figure(1)
df11_count.cumsum().plot()
df1_count.cumsum().plot()
plt.xlim([15,45])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 5 neighbors have moved','No neighborhood effect'])

fig = figure(figsize=(15, 8))
plot3 = plt.figure(2)
df12_count.cumsum().plot()
df1_count.cumsum().plot()
plt.xlim([15,45])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 7 neighbors have moved','No neighborhood effect'])

fig = figure(figsize=(15, 8))
plot4 = plt.figure(3)
df13_count.cumsum().plot()
df1_count.cumsum().plot()
plt.xlim([15,45])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 10 neighbors have moved','No neighborhood effect'])

plt.show()

# %%
df1_nb = pd.read_csv('150M_10_No_NB.csv')
df11_nb = pd.read_csv('150M_10_3of5_NB.csv')
df12_nb = pd.read_csv('150M_10_3of7_NB.csv')
df13_nb = pd.read_csv('150M_10_3of10_NB.csv')

# %%
index_name = df11_nb[(df11_nb['normal_inf?'] == False) & (df11_nb['poor_inf?'] == False)].index 
df11_nb.drop(index_name, inplace = True) 

index_name = df12_nb[(df12_nb['normal_inf?'] == False) & (df12_nb['poor_inf?'] == False)].index 
df12_nb.drop(index_name, inplace = True)

index_name = df13_nb[(df13_nb['normal_inf?'] == False) & (df13_nb['poor_inf?'] == False)].index 
df13_nb.drop(index_name, inplace = True)

# %%
df1_count_nb = df1.mot_year.value_counts().sort_index()
df11_count_nb = df11_nb.mot_year.value_counts().sort_index()
df12_count_nb = df12_nb.mot_year.value_counts().sort_index()
df13_count_nb = df13_nb.mot_year.value_counts().sort_index()
# df13_count_nb

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year, Moving Cost Multiplier = 150)')

df11_count_nb.cumsum().plot()
df12_count_nb.cumsum().plot()
df13_count_nb.cumsum().plot()

plt.xlim([5,36])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved','3 out 7 neighbors have moved','3 out 10 neighbors have moved']) 

plt.show()

# %%
df1_nb_normal = pd.read_csv('150M_10_No_NB.csv')
df11_nb_normal = pd.read_csv('150M_10_3of5_NB.csv')
df12_nb_normal = pd.read_csv('150M_10_3of7_NB.csv')
df13_nb_normal = pd.read_csv('150M_10_3of10_NB.csv')

df1_nb_poor = pd.read_csv('150M_10_No_NB.csv')
df11_nb_poor = pd.read_csv('150M_10_3of5_NB.csv')
df12_nb_poor = pd.read_csv('150M_10_3of7_NB.csv')
df13_nb_poor = pd.read_csv('150M_10_3of10_NB.csv')

# %%
index_name = df11_nb_normal[(df11_nb_normal['normal_inf?'] == False)].index 
df11_nb_normal.drop(index_name, inplace = True) 

index_name = df12_nb_normal[(df12_nb_normal['normal_inf?'] == False)].index 
df12_nb_normal.drop(index_name, inplace = True)

index_name = df13_nb_normal[(df13_nb_normal['normal_inf?'] == False)].index 
df13_nb_normal.drop(index_name, inplace = True)


index_name = df11_nb_poor[(df11_nb_poor['poor_inf?'] == False)].index 
df11_nb_poor.drop(index_name, inplace = True) 

index_name = df12_nb_poor[(df12_nb_poor['poor_inf?'] == False)].index 
df12_nb_poor.drop(index_name, inplace = True)

index_name = df13_nb_poor[(df13_nb_poor['poor_inf?'] == False)].index 
df13_nb_poor.drop(index_name, inplace = True)

# %%
df11_count_nb_normal = df11_nb_normal.mot_year.value_counts().sort_index()
df12_count_nb_normal = df12_nb_normal.mot_year.value_counts().sort_index()
df13_count_nb_normal = df13_nb_normal.mot_year.value_counts().sort_index()


df11_count_nb_poor = df11_nb_poor.mot_year.value_counts().sort_index()
df12_count_nb_poor = df12_nb_poor.mot_year.value_counts().sort_index()
df13_count_nb_poor = df13_nb_poor.mot_year.value_counts().sort_index()

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year, Moving Cost Multiplier = 150)')

df11_count_nb.cumsum().plot(color='green')
df11_count_nb_normal.cumsum().plot(color='green', Marker="s")
df11_count_nb_poor.cumsum().plot(color='green',Marker="+")

df12_count_nb.cumsum().plot(color='pink')
df12_count_nb_normal.cumsum().plot(color='pink', marker="s")
df12_count_nb_poor.cumsum().plot(color='pink', marker="+")


df13_count_nb.cumsum().plot(color='black')
df13_count_nb_normal.cumsum().plot(color='black', marker="s")
df13_count_nb_poor.cumsum().plot(color='black', marker="+")

plt.xlim([15,45])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved','Middle income', 'Low income',
                   '3 out 7 neighbors have moved','Middle income', 'Low income',
                   '3 out 10 neighbors have moved','Middle income', 'Low income']) 

plt.show()

# %%
df1_nb_Obj = pd.read_csv('150M_10_No_NB_Obj.csv')
df11_nb_Obj = pd.read_csv('150M_10_3of5_NB_Obj.csv')
df12_nb_Obj = pd.read_csv('150M_10_3of7_NB_Obj.csv')
df13_nb_Obj = pd.read_csv('150M_10_3of10_NB_Obj.csv')

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Objective value of the following year (10 year, Moving Cost Multiplier = 150)')

df1_nb_Obj.Objective.plot(color='orange')
df11_nb_Obj.Objective.plot(color='green')
df12_nb_Obj.Objective.plot(color='pink')
df13_nb_Obj.Objective.plot(color='black')

plt.xlim([0,80])

plt.ylabel('Objective Value')
plt.xlabel('Relocation year')

plt.legend(labels=['No neighborhood effect','3 out 5 neighbors have moved','3 out 7 neighbors have moved','3 out 10 neighbors have moved']) 

plt.show()

# %% [markdown]
# # 100-year flood

# %%
df1 = pd.read_csv('50M_10_No_NB.csv')
df11 = pd.read_csv('50M_10_3of5_NB.csv')
df12 = pd.read_csv('50M_10_3of7_NB.csv')
df13 = pd.read_csv('50M_10_3of10_NB.csv')

# %%
df1_count = df1.mot_year.value_counts().sort_index()
df11_count = df11.mot_year.value_counts().sort_index()
df12_count = df12.mot_year.value_counts().sort_index()
df13_count = df13.mot_year.value_counts().sort_index()
# df13_count

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year)')

df1_count.cumsum().plot()
df11_count.cumsum().plot()
df12_count.cumsum().plot()
df13_count.cumsum().plot()

plt.xlim([5,15])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['No neighborhood effect','self-moved + 3 out 5 neighbors have moved','self-moved + 3 out 7 neighbors have moved','self-moved + 3 out 10 neighbors have moved']) 

plt.show()

# %%
df1_count_ori = df1.ori_year.value_counts().sort_index()
df11_count_ori = df11.ori_year.value_counts().sort_index()
df12_count_ori = df12.ori_year.value_counts().sort_index()
df13_count_ori = df13.ori_year.value_counts().sort_index()
df13_count_ori

# %%
fig = figure(figsize=(15, 8))
plot2 = plt.figure(1)
df11_count.cumsum().plot()
df1_count.cumsum().plot()
plt.xlim([0,15])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 5 neighbors have moved','No neighborhood effect'])

fig = figure(figsize=(15, 8))
plot3 = plt.figure(2)
df12_count.cumsum().plot()
df1_count.cumsum().plot()
plt.xlim([0,15])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 7 neighbors have moved','No neighborhood effect'])

fig = figure(figsize=(15, 8))
plot4 = plt.figure(3)
df13_count.cumsum().plot()
df1_count.cumsum().plot()
plt.xlim([0,15])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 10 neighbors have moved','No neighborhood effect'])

plt.show()

# %%
df1_nb = pd.read_csv('50M_10_No_NB.csv')
df11_nb = pd.read_csv('50M_10_3of5_NB.csv')
df12_nb = pd.read_csv('50M_10_3of7_NB.csv')
df13_nb = pd.read_csv('50M_10_3of10_NB.csv')

# %%
index_name = df11_nb[(df11_nb['normal_inf?'] == False) & (df11_nb['poor_inf?'] == False)].index 
df11_nb.drop(index_name, inplace = True) 

index_name = df12_nb[(df12_nb['normal_inf?'] == False) & (df12_nb['poor_inf?'] == False)].index 
df12_nb.drop(index_name, inplace = True)

index_name = df13_nb[(df13_nb['normal_inf?'] == False) & (df13_nb['poor_inf?'] == False)].index 
df13_nb.drop(index_name, inplace = True)

# %%
df1_count_nb = df1.mot_year.value_counts().sort_index()
df11_count_nb = df11_nb.mot_year.value_counts().sort_index()
df12_count_nb = df12_nb.mot_year.value_counts().sort_index()
df13_count_nb = df13_nb.mot_year.value_counts().sort_index()
# df13_count_nb

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year)')

df11_count_nb.cumsum().plot()
df12_count_nb.cumsum().plot()
df13_count_nb.cumsum().plot()

plt.xlim([4,15])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved','3 out 7 neighbors have moved','3 out 10 neighbors have moved']) 

plt.show()

# %%
df1_nb_normal = pd.read_csv('50M_10_No_NB.csv')
df11_nb_normal = pd.read_csv('50M_10_3of5_NB.csv')
df12_nb_normal = pd.read_csv('50M_10_3of7_NB.csv')
df13_nb_normal = pd.read_csv('50M_10_3of10_NB.csv')

df1_nb_poor = pd.read_csv('50M_10_No_NB.csv')
df11_nb_poor = pd.read_csv('50M_10_3of5_NB.csv')
df12_nb_poor = pd.read_csv('50M_10_3of7_NB.csv')
df13_nb_poor = pd.read_csv('50M_10_3of10_NB.csv')

# %%
index_name = df11_nb_normal[(df11_nb_normal['normal_inf?'] == False)].index 
df11_nb_normal.drop(index_name, inplace = True) 

index_name = df12_nb_normal[(df12_nb_normal['normal_inf?'] == False)].index 
df12_nb_normal.drop(index_name, inplace = True)

index_name = df13_nb_normal[(df13_nb_normal['normal_inf?'] == False)].index 
df13_nb_normal.drop(index_name, inplace = True)


index_name = df11_nb_poor[(df11_nb_poor['poor_inf?'] == False)].index 
df11_nb_poor.drop(index_name, inplace = True) 

index_name = df12_nb_poor[(df12_nb_poor['poor_inf?'] == False)].index 
df12_nb_poor.drop(index_name, inplace = True)

index_name = df13_nb_poor[(df13_nb_poor['poor_inf?'] == False)].index 
df13_nb_poor.drop(index_name, inplace = True)

# %%
df11_count_nb_normal = df11_nb_normal.mot_year.value_counts().sort_index()
df12_count_nb_normal = df12_nb_normal.mot_year.value_counts().sort_index()
df13_count_nb_normal = df13_nb_normal.mot_year.value_counts().sort_index()


df11_count_nb_poor = df11_nb_poor.mot_year.value_counts().sort_index()
df12_count_nb_poor = df12_nb_poor.mot_year.value_counts().sort_index()
df13_count_nb_poor = df13_nb_poor.mot_year.value_counts().sort_index()

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year)')

df11_count_nb.cumsum().plot(color='green')
df11_count_nb_normal.cumsum().plot(color='green', Marker="o")
df11_count_nb_poor.cumsum().plot(color='green',Marker="s")

df12_count_nb.cumsum().plot(color='pink')
df12_count_nb_normal.cumsum().plot(color='pink', marker="s")
df12_count_nb_poor.cumsum().plot(color='pink', marker="o")


df13_count_nb.cumsum().plot(color='black')
df13_count_nb_normal.cumsum().plot(color='black', marker="s")
df13_count_nb_poor.cumsum().plot(color='black', marker="o")

plt.xlim([5,15])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved','Middle income', 'Low income'
                   '3 out 7 neighbors have moved','Middle income', 'Low income'
                   '3 out 10 neighbors have moved','Middle income', 'Low income']) 

plt.show()
