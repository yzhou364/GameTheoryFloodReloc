# %%
import pandas as pd 
from pandas import DataFrame
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, show, savefig, xlim, figure, \
                ylim, legend, boxplot, setp, axes

# %%
df2_old300k = pd.read_csv('old300k.csv')

# %%
df2_old300k = df2_old300k.sort_values(['Subsidy'])

# %%
df2_old300k
# Out:
#     Subsidy    OBJECTIVE
# 1         0   15600000.0
# 3      1000   18600000.0
# 0      2000   21500000.0
# 2      3000   24400000.0
# 5      4000   27100000.0
# 6      5000   29800000.0
# 4      6000   32700000.0
# 7      7000   35600000.0
# 8      8000   38200000.0
# 9      9000   41000000.0
# 10    10000   43900000.0
# 11    11000   46800000.0
# 12    12000   49700000.0
# 13    13000   52700000.0
# 14    14000   55300000.0
# 15    15000   58000000.0
# 16    16000   61000000.0
# 17    17000   63800000.0
# 18    18000   66600000.0
# 19    19000   69400000.0
# 20    20000   72200000.0
# 21    21000   75100000.0
# 22    22000   78000000.0
# 23    23000   80900000.0
# 24    24000   83800000.0
# 25    25000   86600000.0
# 26    26000   89500000.0
# 27    27000   92400000.0
# 28    28000   95300000.0
# 29    29000   98200000.0
# 30    30000  101000000.0
# 31    31000  104000000.0
# 32    32000  107000000.0
# 33    33000  110000000.0
# 34    34000  113000000.0
# 35    35000  116000000.0
# 36    36000  118000000.0
# 37    37000  121000000.0
# 38    38000  124000000.0
# 39    39000  127000000.0
# 40    40000  130000000.0
# 41    41000  133000000.0
# 42    42000  136000000.0
# 43    43000  139000000.0
# 45    44000  142000000.0
# 44    45000  145000000.0
# 46    46000  148000000.0
# 47    47000  151000000.0
# 49    48000  153000000.0
# 48    49000  156000000.0
# 50    50000  159000000.0

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_old300k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year, MC+300k)')

plt.savefig('MC+300k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_new300k = pd.read_csv('new300k.csv')

# %%
df2_new300k = df2_new300k.sort_values(['Subsidy'])

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_new300k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year, MC+300k)')

plt.savefig('MC+300k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_new300k1 = pd.read_csv('new300k1.csv')

# %%
df2_new300k1 = df2_new300k1.sort_values(['Subsidy'])

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_new300k1.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year, MC+300k)')

plt.savefig('MC+300k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_new500k = pd.read_csv('new500k.csv')

# %%
df2_new500k = df2_new500k.sort_values(['Subsidy'])

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_new500k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year,MC+500k)')

plt.savefig('MC+500k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_new800k = pd.read_csv('new800k.csv')

# %%
df2_new800k = df2_new800k.sort_values(['Subsidy'])

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_new800k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year,MC+800k)')

plt.savefig('MC+800k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_new1m = pd.read_csv('new1m.csv')

# %%
df2_new1m = df2_new1m.sort_values(['Subsidy'])

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_new1m.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year,MC+1M)')

plt.savefig('MC+1M.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# clear current figure
plt.clf()
# plt.figure(figsize=(216,288))

x = df2_new500k.Subsidy
y1 = df2_new300k.OBJECTIVE
y2 = df2_new500k.OBJECTIVE
#y3 = df2_new800k.OBJECTIVE
#y4 = df2_new1m.OBJECTIVE

plot(x,y1)
plot(x,y2)
#plot(x,y3)
#plot(x,y4)
plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year)')

plt.legend(labels=['MC+300k','MC+500k','MC+800k','MC+1M']) 

plt.savefig('MC.png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# # 100 Year Flood

# %%
df2_new300k_100 = pd.read_csv('new300k_100.csv')

# %%
df2_new300k_100 = df2_new300k_100.sort_values(['Subsidy'])

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_new300k_100.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (100 year, MC+300k)')

plt.savefig('100y_MC+300k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_new500k_100 = pd.read_csv('new500k_100.csv')

# %%
df2_new500k_100 = df2_new500k_100.sort_values(['Subsidy'])

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_new500k_100.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (100 year, MC+500k)')

plt.savefig('100y_MC+500k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_new800k_100 = pd.read_csv('new800k_100.csv')

# %%
df2_new800k_100 = df2_new800k_100.sort_values(['Subsidy'])

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_new800k_100.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (100 year, MC+800k)')

plt.savefig('100_MC+800k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_new1m_100 = pd.read_csv('new1m_100.csv')

# %%
df2_new1m_100 = df2_new1m_100.sort_values(['Subsidy'])

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_new1m_100.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (100 year, MC+1m)')

plt.savefig('100y_MC+1m.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# clear current figure
plt.clf()
# plt.figure(figsize=(216,288))

x1 = df2_new300k_100.Subsidy
x2 = df2_new500k_100.Subsidy
x3 = df2_new800k_100.Subsidy
x4 = df2_new1m_100.Subsidy
y1 = df2_new300k_100.OBJECTIVE
y2 = df2_new500k_100.OBJECTIVE
y3 = df2_new800k_100.OBJECTIVE
y4 = df2_new1m_100.OBJECTIVE

plot(x1,y1)
plot(x2,y2)
plot(x3,y3)
plot(x4,y4)

plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (100 year)')

plt.legend(labels=['MC+300k','MC+500k','MC+800k','MC+1M']) 

plt.savefig('MC_100.png', dpi=300, bbox_inches='tight')

plt.show()
