# %%
import pandas as pd 
from pandas import DataFrame
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, show, savefig, xlim, figure, \
                ylim, legend, boxplot, setp, axes

# %%
df2_1_300k = pd.read_csv('1_300k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_1_300k.plot(x = "Subsidy_percentage", y = "OBJECTIVE")


plt.xlabel('Subsidy_percentage (x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value (Multiple, Moving Cost = THP+300k)')

plt.savefig('MC+300k.png', dpi=300, bbox_inches='tight')

plt.show()

## There is a dropping objective value at 0% - 3% subsidy

# %%
df2_11_300k = pd.read_csv('11_300k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_11_300k.plot(x = "Subsidy_percentage", y = "OBJECTIVE")


plt.xlabel('Subsidy_percentage (x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value (Multiple, Moving Cost = THP+300k)')

plt.savefig('THP+300k.png', dpi=300, bbox_inches='tight')

plt.show()

## There is a dropping objective value at 0% - 3% subsidy

# %%
df2_1_500k = pd.read_csv('1_500k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_1_500k.plot(x = "Subsidy_percentage", y = "OBJECTIVE")


plt.xlabel('Subsidy_percentage(x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value (Multiple, Moving Cost = THP+500k)')

plt.savefig('MC+500k.png', dpi=300, bbox_inches='tight')

plt.show()
## There is a dropping objective value at 1% - 4% subsidy

# %%
df2_11_500k = pd.read_csv('11_500k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_11_500k.plot(x = "Subsidy_percentage", y = "OBJECTIVE")


plt.xlabel('Subsidy_percentage(x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value (Multiple, Moving Cost = THP+500k)')

plt.savefig('THP+500k.png', dpi=300, bbox_inches='tight')

plt.show()
## There is a dropping objective value at 1% - 4% subsidy

# %%
df2_1_800k = pd.read_csv('1_800k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_1_800k.plot(x = "Subsidy_percentage", y = "OBJECTIVE")


plt.xlabel('Subsidy_percentage(x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value (Multiple, Moving Cost = THP+800k)')

plt.savefig('MC+800k.png', dpi=300, bbox_inches='tight')

plt.show()
## There is a dropping objective value at 1% - 4% subsidy

# %%
df2_11_800k = pd.read_csv('11_800k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_11_800k.plot(x = "Subsidy_percentage", y = "OBJECTIVE")


plt.xlabel('Subsidy_percentage(x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value (Multiple, Moving Cost = THP+800k)')

plt.savefig('THP+800k.png', dpi=300, bbox_inches='tight')

plt.show()
## There is a dropping objective value at 1% - 4% subsidy

# %%
df2_1_1m = pd.read_csv('1_1m.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_1_1m.plot(x = "Subsidy_percentage", y = "OBJECTIVE")


plt.xlabel('Subsidy_percentage(x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value (Multiple, Moving Cost = THP+1M)')

plt.savefig('MC+1M.png', dpi=300, bbox_inches='tight')

plt.show()
## There is a dropping objective value at 2% - 7% subsidy

# %%
df2_11_1m = pd.read_csv('11_1m.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_11_1m.plot(x = "Subsidy_percentage", y = "OBJECTIVE")


plt.xlabel('Subsidy_percentage(x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value (Multiple, Moving Cost = THP+1M)')

plt.savefig('THP+1M.png', dpi=300, bbox_inches='tight')

plt.show()
## There is a dropping objective value at 2% - 7% subsidy

# %%
# clear current figure
plt.clf()
# plt.figure(figsize=(216,288))

x1 = df2_1_300k.Subsidy_percentage
x2 = df2_1_500k.Subsidy_percentage
x3 = df2_1_800k.Subsidy_percentage
x4 = df2_1_1m.Subsidy_percentage
y1 = df2_1_300k.OBJECTIVE
y2 = df2_1_500k.OBJECTIVE
y3 = df2_1_800k.OBJECTIVE
y4 = df2_1_1m.OBJECTIVE

plot(x1,y1)
plot(x2,y2)
plot(x3,y3)
plot(x4,y4)

plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year)')

plt.legend(labels=['THP+300k','THP+500k','THP+800k','THP+1M']) 

plt.savefig('MC.png', dpi=300, bbox_inches='tight')

plt.show()
