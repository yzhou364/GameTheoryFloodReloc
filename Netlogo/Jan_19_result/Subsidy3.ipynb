# %%
import pandas as pd 
from pandas import DataFrame
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, show, savefig, xlim, figure, \
                ylim, legend, boxplot, setp, axes

# %%
df2_300k = pd.read_csv('300k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_300k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year, MC+300k)')

plt.savefig('MC+300k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_500k = pd.read_csv('500k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_500k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year,MC+500k)')

plt.savefig('MC+500k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_800k = pd.read_csv('800k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_800k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year,MC+800k)')

plt.savefig('MC+800k.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_1m = pd.read_csv('1m.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_1m.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('OObjective value (10 year,MC+1M)')

plt.savefig('MC+1M.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# clear current figure
plt.clf()
# plt.figure(figsize=(216,288))

x = df2_500k.Subsidy
y1 = df2_300k.OBJECTIVE
y2 = df2_500k.OBJECTIVE
y3 = df2_800k.OBJECTIVE
y4 = df2_1m.OBJECTIVE

plot(x,y1)
plot(x,y2)
plot(x,y3)
plot(x,y4)

plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year)')

plt.legend(labels=['MC+300k','MC+500k','MC+800k','MC+1M']) 

plt.savefig('MC.png', dpi=300, bbox_inches='tight')

plt.show()
