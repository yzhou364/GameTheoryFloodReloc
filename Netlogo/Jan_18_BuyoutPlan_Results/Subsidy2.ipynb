# %%
import pandas as pd 
from pandas import DataFrame
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, show, savefig, xlim, figure, \
                ylim, legend, boxplot, setp, axes

# %%
df1_10 = pd.read_csv('01_19_10_Perc.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df1_10.plot(x = "Subsidy_percentage", y = "OBJECTIVE")

# plt.xlim([0.45,0.47])
plt.xlabel('Subsidy Percentage (x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value for House Price Percentage subsidy (10 year)')

plt.savefig('HP_Perc_Subsidy_10.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df1_100 = pd.read_csv('01_19_100_Perc.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df1_100.plot(x = "Subsidy_percentage", y = "OBJECTIVE")

# plt.xlim([0.45,0.47])
plt.xlabel('Subsidy Percentage (x100%)')
plt.ylabel('Objective Value') 
plt.title('Objective value for House Price Percentage subsidy (100 year)')

plt.savefig('HP_Perc_Subsidy_100.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df2_500k = pd.read_csv('500k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_500k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (10 year)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_5001k = pd.read_csv('5001k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_5001k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (10 year)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_41k = pd.read_csv('41k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_41k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (10 year)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_42k = pd.read_csv('42.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_42k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (10 year)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_1 = pd.read_csv('1.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_1.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value (10 year, MC+800k)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_400k = pd.read_csv('400k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))

df2_400k.plot()
df2_42k.plot()


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (10 year)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_4001k = pd.read_csv('4001k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_4001k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (10 year)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_4002k = pd.read_csv('4002.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_4002k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (10 year)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_800k = pd.read_csv('800k.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_800k.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (10 year)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_10 = pd.read_csv('01_19_10_Fixed.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_10.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (10 year)')

plt.savefig('HP_Fixed_Subsidy_10.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df2_100 = pd.read_csv('01_19_100_Fixed.csv')

# %%
# clear current figure
plt.clf()
plt.figure(figsize=(216,288))
df2_100.plot(x = "Subsidy", y = "OBJECTIVE")


plt.xlabel('Subsidy')
plt.ylabel('Objective Value') 
plt.title('Objective value for fixed amount of subsidy (100 year)')

plt.savefig('HP_Fixed_Subsidy_100.png', dpi=300, bbox_inches='tight')

plt.show()
