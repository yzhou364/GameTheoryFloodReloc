# %%
import pandas as pd 
from pandas import DataFrame
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, show, savefig, xlim, figure, \
                ylim, legend, boxplot, setp, axes

# %% [markdown]
# # Condition

# %%
# from PIL import Image
# myImage = Image.open("");
# myImage

# %% [markdown]
# # 10-year flood

# %%
df1 = pd.read_csv('10_No_NB.csv')
df11 = pd.read_csv('10_3of5_NB.csv')
df12 = pd.read_csv('10_3of7_NB.csv')
df13 = pd.read_csv('10_3of10_NB.csv')
# df11
# Out:
#        who  color  heading        xcor        ycor       shape label  \
# 0        0     19      262 -664.795536  146.777179    "circle"    ""
# 1        1     89      303 -832.836964  111.764114  "triangle"    ""
# 2        2     39       32 -250.574776  517.364636  "triangle"    ""
# 3        3     39      206 -664.866484   88.138276  "triangle"    ""
# 4        4     29      262 -465.158394  513.367872  "triangle"    ""
# ...    ...    ...      ...         ...         ...         ...   ...
# 5861  5861     25      166 -516.111213  671.358269  "triangle"    ""
# 5862  5862     35      236 -609.715881  545.472051  "triangle"    ""
# 5863  5863     39      345 -304.566554  599.818571  "triangle"    ""
# 5864  5864     59      127 -389.728356  449.963599  "triangle"    ""
# 5865  5865     25      158 -516.371357  504.948655  "triangle"    ""
#
#       label-color            breed  hidden?  ...  damage_pct_100y  moved?  \
# 0             9.9    {breed poors}    False  ...            0.705    True
# 1             9.9  {breed normals}    False  ...            0.587    True
# 2             9.9  {breed normals}    False  ...            0.524    True
# 3             9.9  {breed normals}    False  ...            0.632    True
# 4             9.9  {breed normals}    False  ...            0.407    True
# ...           ...              ...      ...  ...              ...     ...
# 5861          9.9  {breed normals}    False  ...            0.000   False
# 5862          9.9  {breed normals}    False  ...            0.000   False
# 5863          9.9  {breed normals}    False  ...            0.407    True
# 5864          9.9  {breed normals}    False  ...            0.587    True
# 5865          9.9  {breed normals}    False  ...            0.263   False
#
#      mot_year  ori_moved?  ori_year                           nearhouse  move  \
# 0           1        True         1   {turtles 250 1271 5257 1701 4599}     0
# 1           0        True         0                                   0     0
# 2           0        True         0                                   0     0
# 3           0        True         0                                   0     0
# 4           0        True         0                                   0     0
# ...       ...         ...       ...                                 ...   ...
# 5861      200       False       200    {turtles 4302 354 302 3379 4483}     0
# 5862      200       False       200  {turtles 3885 1349 2594 5525 5259}     0
# 5863        0        True         0                                   0     0
# 5864        0        True         0                                   0     0
# 5865      200       False       200   {turtles 3123 4951 190 4601 1293}     0
#
#      nbpast_move  normal_inf?  poor_inf?
# 0              2            0          0
# 1              2            0          0
# 2              2            0          0
# 3              2            0          0
# 4              2            0          0
# ...          ...          ...        ...
# 5861           2            0          0
# 5862           2            0          0
# 5863           2            0          0
# 5864           2            0          0
# 5865           2            0          0
#
# [5866 rows x 38 columns]

# %%
df1_count = df1.mot_year.value_counts().sort_index()
df11_count = df11.mot_year.value_counts().sort_index()
df12_count = df12.mot_year.value_counts().sort_index()
df13_count = df13.mot_year.value_counts().sort_index()
df11_count
# Out:
# 0      2667
# 1       173
# 2       115
# 3        81
# 4        19
# 5         4
# 6        11
# 7        10
# 8        14
# 9         4
# 10        1
# 200    2767
# Name: mot_year, dtype: int64

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year)')

df1_count.cumsum().plot(ds='steps-post')
df11_count.cumsum().plot(ds='steps-post')
df12_count.cumsum().plot(ds='steps-post')
df13_count.cumsum().plot(ds='steps-post')

plt.xlim([0,80])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['No neighborhood effect','self-moved + 3 out 5 neighbors have moved','self-moved + 3 out 7 neighbors have moved','self-moved + 3 out 10 neighbors have moved']) 

plt.show()

# %%
df1_count_ori = df1.ori_year.value_counts().sort_index()
df11_count_ori = df11.ori_year.value_counts().sort_index()
df12_count_ori = df12.ori_year.value_counts().sort_index()
df13_count_ori = df13.ori_year.value_counts().sort_index()
df13_count_ori
# Out:
# 0      2510
# 1       218
# 2       128
# 3        61
# 4        27
# 5         5
# 6        12
# 7         7
# 8        13
# 9         5
# 10        1
# 200    2879
# Name: ori_year, dtype: int64

# %%
fig = figure(figsize=(15, 8))
plot2 = plt.figure(1)
df11_count.cumsum().plot(ds='steps-post')
df1_count.cumsum().plot(ds='steps-post')
plt.xlim([0,80])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 5 neighbors have moved','No neighborhood effect'])

fig = figure(figsize=(15, 8))
plot3 = plt.figure(2)
df12_count.cumsum().plot(ds='steps-post')
df1_count.cumsum().plot(ds='steps-post')
plt.xlim([0,80])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 7 neighbors have moved','No neighborhood effect'])

fig = figure(figsize=(15, 8))
plot4 = plt.figure(3)
df13_count.cumsum().plot(ds='steps-post')
df1_count.cumsum().plot(ds='steps-post')
plt.xlim([0,80])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 10 neighbors have moved','No neighborhood effect'])

plt.show()

# %%
df1_nb = pd.read_csv('10_No_NB.csv')
df11_nb = pd.read_csv('10_3of5_NB.csv')
df12_nb = pd.read_csv('10_3of7_NB.csv')
df13_nb = pd.read_csv('10_3of10_NB.csv')

# %%
index_name = df11_nb[(df11_nb['normal_inf?'] == '0') & (df11_nb['poor_inf?'] == '0')].index 
df11_nb.drop(index_name, inplace = True) 

index_name = df12_nb[(df12_nb['normal_inf?'] == '0') & (df12_nb['poor_inf?'] == '0')].index 
df12_nb.drop(index_name, inplace = True)

index_name = df13_nb[(df13_nb['normal_inf?'] == '0') & (df13_nb['poor_inf?'] == '0')].index 
df13_nb.drop(index_name, inplace = True)

# %%
# df13_nb

# %%
df1_count_nb = df1.mot_year.value_counts().sort_index()
df11_count_nb = df11_nb.mot_year.value_counts().sort_index()
df12_count_nb = df12_nb.mot_year.value_counts().sort_index()
df13_count_nb = df13_nb.mot_year.value_counts().sort_index()
df13_count_nb
# Out:
# 0     321
# 1     194
# 2     109
# 3      80
# 4      65
# 5      39
# 6      24
# 7      11
# 8      12
# 9      21
# 10     16
# 11     28
# 12     24
# 13     17
# 14      7
# 15      5
# 16      6
# 17     10
# 18     13
# 19     14
# 20      5
# 21      3
# Name: mot_year, dtype: int64

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year)')

df11_count_nb.cumsum().plot(ds='steps-post')
df12_count_nb.cumsum().plot(ds='steps-post')
df13_count_nb.cumsum().plot(ds='steps-post')

plt.xlim([0,80])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved','3 out 7 neighbors have moved','3 out 10 neighbors have moved']) 

plt.show()

# %%
df1_nb_normal = pd.read_csv('10_No_NB.csv')
df11_nb_normal = pd.read_csv('10_3of5_NB.csv')
df12_nb_normal = pd.read_csv('10_3of7_NB.csv')
df13_nb_normal = pd.read_csv('10_3of10_NB.csv')

df1_nb_poor = pd.read_csv('10_No_NB.csv')
df11_nb_poor = pd.read_csv('10_3of5_NB.csv')
df12_nb_poor = pd.read_csv('10_3of7_NB.csv')
df13_nb_poor = pd.read_csv('10_3of10_NB.csv')

# %%
index_name = df11_nb_normal[(df11_nb_normal['normal_inf?'] == '0')].index 
df11_nb_normal.drop(index_name, inplace = True) 

index_name = df12_nb_normal[(df12_nb_normal['normal_inf?'] == '0')].index 
df12_nb_normal.drop(index_name, inplace = True)

index_name = df13_nb_normal[(df13_nb_normal['normal_inf?'] == '0')].index 
df13_nb_normal.drop(index_name, inplace = True)


index_name = df11_nb_poor[(df11_nb_poor['poor_inf?'] == '0')].index 
df11_nb_poor.drop(index_name, inplace = True) 

index_name = df12_nb_poor[(df12_nb_poor['poor_inf?'] == '0')].index 
df12_nb_poor.drop(index_name, inplace = True)

index_name = df13_nb_poor[(df13_nb_poor['poor_inf?'] == '0')].index 
df13_nb_poor.drop(index_name, inplace = True)

# %%
df11_count_nb_normal = df11_nb_normal.mot_year.value_counts().sort_index()
df12_count_nb_normal = df12_nb_normal.mot_year.value_counts().sort_index()
df13_count_nb_normal = df13_nb_normal.mot_year.value_counts().sort_index()


df11_count_nb_poor = df11_nb_poor.mot_year.value_counts().sort_index()
df12_count_nb_poor = df12_nb_poor.mot_year.value_counts().sort_index()
df13_count_nb_poor = df13_nb_poor.mot_year.value_counts().sort_index()

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year)')

df11_count_nb.cumsum().plot(color='green', ds='steps-post')
df11_count_nb_normal.cumsum().plot(color='green', Marker="s", ds='steps-post')
df11_count_nb_poor.cumsum().plot(color='green',Marker="+", ds='steps-post')

df12_count_nb.cumsum().plot(color='pink', ds='steps-post')
df12_count_nb_normal.cumsum().plot(color='pink', marker="s", ds='steps-post')
df12_count_nb_poor.cumsum().plot(color='pink', marker="+", ds='steps-post')


df13_count_nb.cumsum().plot(color='black', ds='steps-post')
df13_count_nb_normal.cumsum().plot(color='black', marker="s", ds='steps-post')
df13_count_nb_poor.cumsum().plot(color='black', marker="+", ds='steps-post')

plt.xlim([0,80])
# plt.ylim([2600,3800])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved','Middle income', 'Low income',
                   '3 out 7 neighbors have moved','Middle income', 'Low income',
                   '3 out 10 neighbors have moved','Middle income', 'Low income']) 

plt.show()

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year)')

df11_count_nb_normal.cumsum().plot(color='green', Marker="s", ds='steps-post')

df12_count_nb_normal.cumsum().plot(color='pink', marker="s", ds='steps-post')

df13_count_nb_normal.cumsum().plot(color='black', marker="s", ds='steps-post')

plt.xlim([0,80])
# plt.ylim([2600,3800])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved - Middle income',
                   '3 out 7 neighbors have moved - Middle income',
                   '3 out 10 neighbors have moved - Middle income']) 

plt.show()

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (10 year)')


df11_count_nb_poor.cumsum().plot(color='green',Marker="+", ds='steps-post')

df12_count_nb_poor.cumsum().plot(color='pink', marker="+", ds='steps-post')

df13_count_nb_poor.cumsum().plot(color='black', marker="+", ds='steps-post')

plt.xlim([0,80])
# plt.ylim([2600,3800])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved - Low income',
                   '3 out 7 neighbors have moved - Low income',
                   '3 out 10 neighbors have moved - Low income']) 

plt.show()

# %%
df1_move_nb = pd.read_csv('10_No_NB.csv')
df11_move_nb = pd.read_csv('10_3of5_NB.csv')
df12_move_nb = pd.read_csv('10_3of7_NB.csv')
df13_move_nb = pd.read_csv('10_3of10_NB.csv')

# %%
# df11_move_nb = df11_move_nb[(df11_move_nb['normal_inf?'] == '0') & (df11_move_nb['poor_inf?'] == '0')]
# df12_move_nb = df12_move_nb[(df12_move_nb['normal_inf?'] == '0') & (df12_move_nb['poor_inf?'] == '0')]
# df13_move_nb = df13_move_nb[(df13_move_nb['normal_inf?'] == '0') & (df13_move_nb['poor_inf?'] == '0')]

# %%
df13_move_nb.breed.value_counts()
# Out:
# {breed normals}    5246
# {breed poors}       620
# Name: breed, dtype: int64

# %%
# df13_move_nb[df13_move_nb['breed']=='{breed poors}']

# %%
df11_move_nb_normal = df11_move_nb[df11_move_nb['breed']=='{breed normals}'].mot_year.value_counts().sort_index().cumsum()
df12_move_nb_normal = df12_move_nb[df12_move_nb['breed']=='{breed normals}'].mot_year.value_counts().sort_index().cumsum()
df13_move_nb_normal = df13_move_nb[df13_move_nb['breed']=='{breed normals}'].mot_year.value_counts().sort_index().cumsum()


df11_move_nb_poor = df11_move_nb[df11_move_nb['breed']=='{breed poors}'].mot_year.value_counts().sort_index().cumsum()
df12_move_nb_poor = df12_move_nb[df12_move_nb['breed']=='{breed poors}'].mot_year.value_counts().sort_index().cumsum()
df13_move_nb_poor = df13_move_nb[df13_move_nb['breed']=='{breed poors}'].mot_year.value_counts().sort_index().cumsum()

# %%
# df13_move_nb_normal

# %%
# df13_move_nb_poor

# %%
# df13_count_nb_poor.cumsum()

# %%
# df13_move_nb_normal

# %%
# df13_count_nb_poor.cumsum()/df13_move_nb_poor

# %%
# df13_count_nb_normal.cumsum()/df13_move_nb_normal

# %%
# df13_move_nb_poor

# %%
# # clear current figure
# plt.clf()
# fig = figure(figsize=(15, 8))
# plt.title('Number of motivated moves of the following year (10 year)')

# # df11_count_nb.cumsum().plot(color='green', ds='steps-post')
# (df11_count_nb_normal.cumsum()/df11_move_nb_normal).plot(color='green', Marker="s", ds='steps-post')
# (df11_count_nb_poor.cumsum()/df11_move_nb_poor).plot(color='green',Marker="+", ds='steps-post')

# # df12_count_nb.cumsum().plot(color='pink', ds='steps-post')
# # df12_count_nb_normal.cumsum().plot(color='pink', marker="s", ds='steps-post')
# # df12_count_nb_poor.cumsum().plot(color='pink', marker="+", ds='steps-post')


# # df13_count_nb.cumsum().plot(color='black', ds='steps-post')
# # df13_count_nb_normal.cumsum().plot(color='black', marker="s", ds='steps-post')
# # df13_count_nb_poor.cumsum().plot(color='black', marker="+", ds='steps-post')

# plt.xlim([0,80])
# # plt.ylim([2600,3800])

# plt.ylabel('Number of moves')
# plt.xlabel('Relocation year')

# plt.legend(labels=['3 out 5 neighbors have moved','Middle income', 'Low income',
#                    '3 out 7 neighbors have moved','Middle income', 'Low income',
#                    '3 out 10 neighbors have moved','Middle income', 'Low income']) 

# plt.show()

# %%
df1_nb_Obj = pd.read_csv('10_No_NB_Obj.csv')
df11_nb_Obj = pd.read_csv('10_3of5_NB_Obj.csv')
df12_nb_Obj = pd.read_csv('10_3of7_NB_Obj.csv')
df13_nb_Obj = pd.read_csv('10_3of10_NB_Obj.csv')

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Objective value of the following year (10 year')

df1_nb_Obj.Objective.plot(color='orange')
df11_nb_Obj.Objective.plot(color='green')
df12_nb_Obj.Objective.plot(color='pink')
df13_nb_Obj.Objective.plot(color='black')

plt.xlim([0,80])

plt.ylabel('Objective Value')
plt.xlabel('Relocation year')

plt.legend(labels=['No neighborhood effect','3 out 5 neighbors have moved','3 out 7 neighbors have moved','3 out 10 neighbors have moved']) 

plt.show()

# %% [markdown]
# # 100-year flood

# %%
df1 = pd.read_csv('100_No_NB.csv')
df11 = pd.read_csv('100_3of5_NB.csv')
df12 = pd.read_csv('100_3of7_NB.csv')
df13 = pd.read_csv('100_3of10_NB.csv')

# %%
df1_count = df1.mot_year.value_counts().sort_index()
df11_count = df11.mot_year.value_counts().sort_index()
df12_count = df12.mot_year.value_counts().sort_index()
df13_count = df13.mot_year.value_counts().sort_index()
# df13_count

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (100 year)')

df1_count.cumsum().plot()
df11_count.cumsum().plot()
df12_count.cumsum().plot()
df13_count.cumsum().plot()

plt.xlim([5,15])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['No neighborhood effect','self-moved + 3 out 5 neighbors have moved','self-moved + 3 out 7 neighbors have moved','self-moved + 3 out 10 neighbors have moved']) 

plt.show()

# %%
df1_count_ori = df1.ori_year.value_counts().sort_index()
df11_count_ori = df11.ori_year.value_counts().sort_index()
df12_count_ori = df12.ori_year.value_counts().sort_index()
df13_count_ori = df13.ori_year.value_counts().sort_index()
df13_count_ori

# %%
fig = figure(figsize=(15, 8))
plot2 = plt.figure(1)
df11_count.cumsum().plot()
df1_count.cumsum().plot()
plt.xlim([0,15])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 5 neighbors have moved','No neighborhood effect'])

fig = figure(figsize=(15, 8))
plot3 = plt.figure(2)
df12_count.cumsum().plot()
df1_count.cumsum().plot()
plt.xlim([0,15])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 7 neighbors have moved','No neighborhood effect'])

fig = figure(figsize=(15, 8))
plot4 = plt.figure(3)
df13_count.cumsum().plot()
df1_count.cumsum().plot()
plt.xlim([0,15])
plt.ylabel('Number of moves')
plt.xlabel('Relocation year')
plt.legend(labels=['self-moved + 3 out 10 neighbors have moved','No neighborhood effect'])

plt.show()

# %%
df1_nb = pd.read_csv('100_No_NB.csv')
df11_nb = pd.read_csv('100_3of5_NB.csv')
df12_nb = pd.read_csv('100_3of7_NB.csv')
df13_nb = pd.read_csv('100_3of10_NB.csv')

# %%
index_name = df11_nb[(df11_nb['normal_inf?'] == False) & (df11_nb['poor_inf?'] == False)].index 
df11_nb.drop(index_name, inplace = True) 

index_name = df12_nb[(df12_nb['normal_inf?'] == False) & (df12_nb['poor_inf?'] == False)].index 
df12_nb.drop(index_name, inplace = True)

index_name = df13_nb[(df13_nb['normal_inf?'] == False) & (df13_nb['poor_inf?'] == False)].index 
df13_nb.drop(index_name, inplace = True)

# %%
df1_count_nb = df1.mot_year.value_counts().sort_index()
df11_count_nb = df11_nb.mot_year.value_counts().sort_index()
df12_count_nb = df12_nb.mot_year.value_counts().sort_index()
df13_count_nb = df13_nb.mot_year.value_counts().sort_index()
# df13_count_nb

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (100 year)')

df11_count_nb.cumsum().plot()
df12_count_nb.cumsum().plot()
df13_count_nb.cumsum().plot()

plt.xlim([4,15])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved','3 out 7 neighbors have moved','3 out 10 neighbors have moved']) 

plt.show()

# %%
df1_nb_normal = pd.read_csv('100_No_NB.csv')
df11_nb_normal = pd.read_csv('100_3of5_NB.csv')
df12_nb_normal = pd.read_csv('100_3of7_NB.csv')
df13_nb_normal = pd.read_csv('100_3of10_NB.csv')

df1_nb_poor = pd.read_csv('100_No_NB.csv')
df11_nb_poor = pd.read_csv('100_3of5_NB.csv')
df12_nb_poor = pd.read_csv('100_3of7_NB.csv')
df13_nb_poor = pd.read_csv('100_3of10_NB.csv')

# %%
index_name = df11_nb_normal[(df11_nb_normal['normal_inf?'] == False)].index 
df11_nb_normal.drop(index_name, inplace = True) 

index_name = df12_nb_normal[(df12_nb_normal['normal_inf?'] == False)].index 
df12_nb_normal.drop(index_name, inplace = True)

index_name = df13_nb_normal[(df13_nb_normal['normal_inf?'] == False)].index 
df13_nb_normal.drop(index_name, inplace = True)


index_name = df11_nb_poor[(df11_nb_poor['poor_inf?'] == False)].index 
df11_nb_poor.drop(index_name, inplace = True) 

index_name = df12_nb_poor[(df12_nb_poor['poor_inf?'] == False)].index 
df12_nb_poor.drop(index_name, inplace = True)

index_name = df13_nb_poor[(df13_nb_poor['poor_inf?'] == False)].index 
df13_nb_poor.drop(index_name, inplace = True)

# %%
df11_count_nb_normal = df11_nb_normal.mot_year.value_counts().sort_index()
df12_count_nb_normal = df12_nb_normal.mot_year.value_counts().sort_index()
df13_count_nb_normal = df13_nb_normal.mot_year.value_counts().sort_index()


df11_count_nb_poor = df11_nb_poor.mot_year.value_counts().sort_index()
df12_count_nb_poor = df12_nb_poor.mot_year.value_counts().sort_index()
df13_count_nb_poor = df13_nb_poor.mot_year.value_counts().sort_index()

# %%
# clear current figure
plt.clf()
fig = figure(figsize=(15, 8))
plt.title('Number of motivated moves of the following year (100 year)')

df11_count_nb.cumsum().plot(color='green')
df11_count_nb_normal.cumsum().plot(color='green', Marker="o")
df11_count_nb_poor.cumsum().plot(color='green',Marker="s")

df12_count_nb.cumsum().plot(color='pink')
df12_count_nb_normal.cumsum().plot(color='pink', marker="s")
df12_count_nb_poor.cumsum().plot(color='pink', marker="o")


df13_count_nb.cumsum().plot(color='black')
df13_count_nb_normal.cumsum().plot(color='black', marker="s")
df13_count_nb_poor.cumsum().plot(color='black', marker="o")

plt.xlim([5,15])

plt.ylabel('Number of moves')
plt.xlabel('Relocation year')

plt.legend(labels=['3 out 5 neighbors have moved','Middle income', 'Low income'
                   '3 out 7 neighbors have moved','Middle income', 'Low income'
                   '3 out 10 neighbors have moved','Middle income', 'Low income']) 

plt.show()
